# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Random Samples ##

# %% [markdown]
# We load in a dataset of all United flights national flights from 6/1/15 to 8/9/15, their destination, and how long they were delayed in minutes.

# %%
united = Table.read_table('united.csv')
united = united.with_column('Row', np.arange(0, united.num_rows))
united
# Out:
# Date   | Flight Number | Destination | Delay | Row
# 6/1/15 | 73            | HNL         | 257   | 0
# 6/1/15 | 217           | EWR         | 28    | 1
# 6/1/15 | 237           | STL         | -3    | 2
# 6/1/15 | 250           | SAN         | 0     | 3
# 6/1/15 | 267           | PHL         | 64    | 4
# 6/1/15 | 273           | SEA         | -6    | 5
# 6/1/15 | 278           | SEA         | -8    | 6
# 6/1/15 | 292           | EWR         | 12    | 7
# 6/1/15 | 300           | HNL         | 20    | 8
# 6/1/15 | 317           | IND         | -10   | 9
# ... (13815 rows omitted)

# %%
# Probability Distribution (assuming this is the entire population)
united_bins = np.arange(-20, 201, 5)
united.hist('Delay', bins = united_bins, unit = 'minute')

# %%
# Empirical Distribution of 10 flights
united_sample = united.sample(10)
united_sample
#united.sample(10).hist('Delay', bins = united_bins, unit = 'minute')
# Out:
# Date    | Flight Number | Destination | Delay | Row
# 6/28/15 | 300           | HNL         | 6     | 4065
# 6/8/15  | 1497          | SEA         | 54    | 1128
# 7/29/15 | 318           | DEN         | -4    | 8719
# 8/5/15  | 1699          | ATL         | 5     | 9922
# 8/23/15 | 506           | LAS         | -2    | 12559
# 8/30/15 | 662           | MSP         | 2     | 13575
# 8/8/15  | 1593          | EWR         | 209   | 10368
# 8/19/15 | 1405          | RNO         | 15    | 12046
# 7/10/15 | 276           | EWR         | -7    | 5823
# 7/17/15 | 1641          | IAD         | 4     | 6999

# %%
united.sample(10).hist('Delay', bins = united_bins, unit = 'minute')

# %%
# Empirical Distribution of 1,000 flights
united.sample(1000).hist('Delay', bins = united_bins, unit = 'minute')

# %% [markdown]
# ## Simulating Statistics ##

# %%
# (Population) Parameter
delays_arr = united.column('Delay')
np.median(delays_arr)
# Out:
# 2.0

# %%
# (Sample) Statistic
united_sample = united.sample(10)
delays_sample_arr = united_sample.column('Delay')
np.median(delays_sample_arr)
# Out:
# -0.5

# %% [markdown]
# ## Empirical Distribution of a Statistic ##

# %%
# Write a function that takes a samples "size" rows from the table and returns the median
def sample_median(size):
    united_sample = united.sample(size)
    delays_sample_arr = united_sample.column('Delay')
    return np.median(delays_sample_arr)

# %%
# Call the function with a sample size = 10
sample_median(10)
# Out:
# 1.5

# %%
# Call the function 1,000 times with a sample size = 10 & store the results in an array using append
sample_medians = make_array()

for i in np.arange(1000):
    simulated_median = sample_median(10)
    sample_medians = np.append(sample_medians,simulated_median)
sample_medians
# Out:
# array([ 15. ,   6. ,   2.5,  12. ,   3.5,  -1. ,   3. ,  -0.5,  -2. ,
#         -1. ,   8. ,  15. ,   1.5,   3. ,   3. ,   9.5,   2.5,   0.5,
#          8. ,  -1. ,   6. ,  13. ,   3.5,   4. ,  12.5,   0. ,  -1. ,
#         27. ,   9.5,   6.5,   4.5,  13.5,   3. ,   2.5,   5.5,  13.5,
#          4. ,   2. ,   3.5,   2.5,   3.5,   4. ,  12. ,  15. ,  -1.5,
#         11. ,   0. ,  -3.5,   2.5,   4. ,   2. ,   3.5,   2.5,   0. ,
#         15. ,   5. ,   1.5,  -0.5,   0. ,   7. ,  -2. ,   5. ,  23. ,
#          1. ,   5.5,  10. ,   6. ,   8.5,   0. ,  -1.5,   6.5,  -2.5,
#          4. ,   2. ,   1.5,   5.5,   2.5,  17. ,  14. ,   4. ,  -2. ,
#         50. ,   6. ,   3. ,   1. ,   5. ,   7.5,   1.5,  11.5,   3.5,
#          4.5,  -0.5,  10.5,   9.5,   9. ,  -0.5,   1.5,  -1. ,   7. ,
#          5.5,  -1. ,   0. ,  13. ,   2. ,   8.5,   7. ,   0.5,   2. ,
#         19.5,   6.5,   1.5,   3.5,   2. ,   4. ,  21.5,   2. ,   2. ,
#          1. ,   1. ,   0.5,  15. ,  12.5,   0.5,   6.5,   5. ,   0. ,
#          1.5,   0. ,   2. ,  15. ,   0.5,   1.5,   4. ,  18.5,   0.5,
#         -1.5,  -0.5,   4. ,  -0.5,   4. ,   0. ,   4. ,   3.5,   5.5,
#         10.5,  20. ,  -0.5,  -2.5,   9. ,   0. ,  22.5,  -0.5,   2. ,
#          6.5,  -1. ,   4.5,   3.5,  -3.5,   8. ,   4.5,   2.5,   4. ,
#          4.5,   9. ,  24. ,   0. ,   1. ,   0.5,  -1.5,   0.5,   0. ,
#         18.5,   1. ,   1. ,   0. ,  14. ,  -1. ,   6. ,   1. ,   4. ,
#          1. ,  -1. ,   1.5,  14. ,   0. ,   9.5,  20.5,   1. ,   0.5,
#         51.5,  -1. ,   3. ,  -1.5,   0. ,  -3.5,   0.5,  10.5,   5.5,
#          1. ,   2.5,   0. ,   0. ,   2. ,  -2. ,   8. ,   7.5,  -0.5,
#         -1.5,   3. ,   4.5,   9.5,   8.5,   0. ,  15.5,   8. ,  -0.5,
#          8. ,   0. ,   9.5,  -1. ,  32. ,  -4. ,  -1. ,   0.5,   0.5,
#          2. ,   6. ,   1. ,   8. ,  -3. ,  -0.5,   1.5,   9.5,   1. ,
#         10. ,   5. ,   4. ,  14.5,  16.5,   3.5,   6.5,   3. ,  19. ,
#          0.5,  17. ,   3. ,  -0.5,  -2.5,   0.5,   4. ,   1.5,   0.5,
#          0. ,   3.5,  -1. ,   4.5,  -4. ,   0.5,   9.5,   1. ,   1. ,
#         10. ,  -3. ,  -1. ,   4. ,  -0.5,   0.5,   3. ,  -0.5,   6.5,
#         -2. ,  14. ,  23. ,  15.5,   3.5,   1.5,  11.5,  18.5,  -0.5,
#          1.5,  14.5,   3.5,   7. ,  -1. ,  15.5,   8.5,   5. ,  11.5,
#          3.5,   1.5,   8. ,   5.5,   2.5,   2.5,   1. ,  19.5,   1. ,
#          3.5,  -1. ,   5.5,   8.5,   6.5,   0. ,  12. ,   0. ,   1. ,
#          3. ,   2.5,   2.5,   6. ,   7. ,   4. ,   0.5,   2.5,   2. ,
#         27.5,  -0.5,  10. ,  -0.5,   7.5,   0. ,   0. ,  10. ,   3. ,
#          8.5,   1.5,   4.5,  -1.5,   0. ,   8. ,  -0.5,   0.5,   6. ,
#         -1.5,   3. ,   2. ,   8. ,  -1. ,  34.5,   2. ,   1.5,   6.5,
#          6.5,  14. ,   1.5,  -1. ,   4. ,   1.5,   5.5,   9. ,   4. ,
#          1.5,   5.5,   0. ,   0. ,   3. ,   0.5,  -3. ,  -0.5,  22. ,
#          3.5,   7. ,   0.5,   4.5,   4. ,   7.5,  -2. ,   8. ,  21. ,
#          0. ,   0. ,  -4. ,   6.5,   1. ,  11. ,  -1.5,  -0.5,  -1.5,
#          1. ,   2. ,   5.5,   1.5,   1. ,   0. ,   8. ,  -1. ,   5.5,
#          7.5,   6.5,   5. ,  -4. ,   4. ,   6.5,   0.5,   2.5,  11.5,
#          3. ,   0.5,  19.5,  19.5,   6. ,   5. ,   6. ,  -0.5,   2.5,
#         -2.5,  18.5,  11. ,  13.5,   9.5,   3.5,  -4. ,   9.5,  -0.5,
#         -2. ,  -1. ,   7. ,   2. ,  13.5,   5. ,   7.5,  44. ,  11. ,
#         15.5,   1.5,   0. ,   8. ,  20. ,  -3. ,   1.5,   9.5,   9.5,
#          4. ,  13. ,  -4. ,   2.5,  -1.5,   9. ,  17. ,   1. ,   2. ,
#          9.5,   4. ,  -1.5,   0. ,   2. ,   8. ,  -3.5,  17. ,  15. ,
#          0.5,   2.5,  -0.5,   9. ,   1. ,  24. ,   7. ,  -0.5,   5.5,
#          7.5,   4. ,  14. ,   0. ,   9.5,  -1. ,  -1. ,   0. ,   0.5,
#          6. ,  12. ,   3.5,   0. ,  -0.5,  26. ,   6. ,  -2. ,   4.5,
#          4. ,  46.5,  -1.5,   4. ,   0.5,   2.5,  -0.5,  23. ,   3.5,
#          1. ,  16.5,   1. ,  50.5,   4. ,   9.5,   8. ,  -0.5,   9. ,
#         16. ,   8. ,   8. ,  -1. ,   2. ,   2. ,  12.5,  -0.5,   8. ,
#          4.5,  10. ,   0.5,  -1. ,  16.5,   4.5,   0.5,  -3.5,  -2.5,
#          2.5,   6.5,   0. ,   1.5,  15. ,   1.5,   0. ,   8.5,   2. ,
#         -1.5,   3. ,   0.5,   2.5,   9. ,   5.5,  10. ,   0.5,   6. ,
#          1. ,   9.5,  -2.5,   2.5,   5. ,  -1. ,   1. ,   0.5,   1.5,
#          5.5,  -0.5,   0.5,   1.5,   6. ,  -0.5,   3. ,   5.5,   1. ,
#          6. ,  -3. ,   7.5,   8.5,  -2. ,  -1. ,  -1.5,   4. ,  14.5,
#         -0.5,  32. ,   0.5,   4. ,  19.5,   9.5,   7. ,  11. ,  -1. ,
#          0. ,   0. ,   5. ,   4. ,   3. ,  10.5,   0. ,   1.5,   6. ,
#          9.5,   4. ,   3. ,  -0.5,   6.5,   0.5,   2.5,  -0.5,   3. ,
#          3.5,   4. ,  10.5,   3.5,  -2.5,   5. ,   0.5,  -1. ,  -3.5,
#         -1. ,   0.5,   3.5,  -1.5,  -1. ,   5. ,   6. ,  28. ,   8.5,
#         -1. ,  -2. ,   0. ,  10. ,  -1.5,  -0.5,   4.5,   9.5,   4. ,
#         -0.5,   0.5,   2. ,   8. ,   4. ,   0. ,   0. ,   3. ,  18.5,
#          0.5,   1. ,   3.5,   2. ,   2.5,   2.5,  -3.5,   2.5,  16.5,
#          6.5,  10.5,   0. ,   0.5,   0. ,   2. ,   3.5,   3.5,  -2. ,
#          0.5,   4. ,   2.5,  -1.5,   4. ,   4. ,   0. ,   5.5,  16. ,
#         -1. ,  22. ,   3. ,   2. ,  26. ,  21.5,   0.5,   2. ,  -3. ,
#          1.5,  -1.5,  -1.5,  -3. ,   9.5,  13. ,   4. ,  -2. ,   7. ,
#         -4. ,  -1. ,  -1.5,   2.5,  11.5,  -0.5,   5. ,  -1. ,   3.5,
#          2. ,   5. ,   8. ,   7. ,  -2.5,   1.5,   2.5,   3.5,  16. ,
#          0. ,   1. ,   0. ,   3. ,  -1.5,   6. ,  -2. ,   4. ,  20. ,
#         14. ,  16. ,   2. ,  21. ,  -0.5,   9. ,   9.5,  -0.5,   2. ,
#          5.5,   1. ,   0. ,   2. ,   0. ,   0.5,   2. ,  40. ,  -2. ,
#         -2.5,   2. ,   4.5,  14.5,   0. ,   9. ,   3.5,  15. ,  -1. ,
#          9.5,   3. ,  -2. ,   6. ,   3. ,  -3.5,  11.5,  -1. ,   1. ,
#          1. ,  12. ,   2.5,   4.5,   7. ,  15. ,   0.5,   4. ,   3. ,
#         13.5,   5. ,  -1.5,   7.5,  10. ,  -2. ,  19. ,   2. ,  11.5,
#          3. ,  36. ,   3. ,   1.5,   2.5,   2. ,  -2.5,   3.5,   3.5,
#          7.5,  26. ,  16. ,  20. ,   0. ,  11.5,   2.5,   2. ,   1. ,
#          7. ,   5.5,  -0.5,   2. ,   0.5,  -0.5,   5.5,   0.5,  10. ,
#         -1. ,  -1. ,   7.5,  10. ,   8. ,   2.5,   2.5,   5. ,   7.5,
#         -2. ,  -1. ,   3.5,  -2. ,  11.5,   9. ,  -0.5,   4.5,   6. ,
#          7.5,   7. ,  -2. ,   4.5,   2.5,  15. ,   5. ,  11. ,   4. ,
#          2.5,  18. ,   6.5,   4.5,  -2. ,   4.5,   2.5,   0. ,   7. ,
#          5. ,  -0.5,   6.5,   0.5,   0. ,  -1. ,   0.5,   4. ,  12.5,
#          6. ,  -0.5,   2. ,  16.5,   4. ,  -0.5,   6.5,   3. ,   6.5,
#         -0.5,  12.5,   9. ,  10.5,   0. ,   0.5,   0.5,   6.5,   7. ,
#          3.5,  23. ,   0.5,   3.5,  -2. ,  14. ,   4. ,   0. ,   0. ,
#          5.5,   2.5,   7. ,   5.5,   0.5,   5. ,  12. ,  11.5,   2. ,
#          1.5,  -5. ,   9. ,   7. ,   0.5,   1.5,  -2.5,   3.5,   8. ,
#          2. ,   2. ,   4. ,   0.5,   3.5,   4. ,   2.5,   1. ,  11. ,
#          3.5,   8.5,   2.5,   9. ,   8.5,  13. ,   6. ,  -1. ,  -1. ,
#          4. ,   1. ,   3. ,   3. ,   3. ,   8. ,   5.5,   6.5,   8. ,
#          3.5,   1.5,  18.5,   6. ,   0.5,  -1.5,   3. ,  11.5,  -1. ,
#         34. ,  -2.5,   6. ,   9. ,   1.5,  16. ,   2. ,   9.5,  10.5,
#         -0.5,  -1.5,   1.5,   4. ,   4. ,   1. ,  -0.5,  -3.5,  10.5,
#          0. ,   5.5,   1. ,  -1.5,  -1. ,   4. ,   1. ,   2.5,   4.5,
#          6.5,   6.5,  -1. ,   7.5,   1.5,  12.5,   2. ,  12. ,   4.5,
#         -1. ,   2.5,   0. ,   7.5,  10. ,  -2. ,   6. ,   2. ,   0.5,
#         11.5,   6. ,  -3. ,  -0.5,  -3. ,  17.5,   0. ,   4. ,   3.5,
#          5. ,  -1. ,   0.5,   8.5,  -1. ,  -1.5,   3. ,   1. ,   2. ,
#          7.5,   2.5,   2.5,   6.5,   1. ,   0. ,   5. ,   3.5,   2. ,
#          6.5,   3.5,   8. ,  -1. ,  -2. ,  12. ,  -1. ,  13.5,   3. ,
#          2. ,  16.5,   6. ,   3.5,  -0.5,  -2.5,  10. ,   2.5,   4. ,
#          0.5,  -1.5,   4.5,  -2. ,  -2. ,   4. ,  -3. ,   8. ,   3. ,   0.5])

# %%
# Show the empirical distribution of sample size = 10
Table().with_column('Sample medians', sample_medians).hist(bins = np.arange(-10,31))

# %%
# Show the empirical distribution of sample size = 1,000
Table().with_column('Sample medians', sample_medians).hist(bins = np.arange(-10,31))

# %% [markdown]
# ## Sampling from categorical distributions with `sample_proportions` ##

# %% [markdown]
# According to the CDC, about 10% of Americans 18 and over suffer from a depressive illness in any given year. [[source](https://www.cdc.gov/workplacehealthpromotion/health-strategies/depression/index.html)]

# %%
# Probability distribution
distribution_in_pop = make_array(0.9, 0.1)
distribution_in_pop
# Out:
# array([ 0.9,  0.1])

# %% [markdown]
# Suppose you have a group of 100 people. Let's simulate how many might suffer from a depressive illness, assuming we can treat each person as if they were drawn randomly from the population of US adults (a dubious assumption).

# %%
# Empirical distribution size 100
distribution_in_sample = sample_proportions(100, distribution_in_pop)
distribution_in_sample
# Out:
# array([ 0.93,  0.07])

# %%
distribution_in_sample = sample_proportions(100000, distribution_in_pop)
distribution_in_sample
# Out:
# array([ 0.9008,  0.0992])

# %% [markdown]
# # Practice
#
# A box contains 3 white balls, 4 black balls, and 1 green ball. You reach in and draw a ball three separate times, replacing the ball you drew before each draw (so the sample_proportions are the same for each draw). Call this procedure of drawing three balls one experiment.
#
# Write a function that simulates this experiment and returns the statistic "number of green balls drawn".

# %%
def num_green():
    # prob_dist is prb of green ball, prob not green ball
    prob_dist = make_array(1/8, 7/8)
    sample_dist = sample_proportions(3, prob_dist)
    number_green = sample_dist.item(0)*3
    return number_green


num_green()
# Out:
# 0.0

# %% [markdown]
# Use the num_green function to simulate the experiment 10,000 times to visualize the distribution of the "number of green balls drawn" statistic.

# %%
green_distr = make_array()

for i in np.arange(10000):
    result = num_green()
    green_distr = np.append(green_distr,result)

# simulate here

results_tbl = Table().with_column('Num Green', green_distr).hist(bins = 4)
